# %%
import scanpy as sc
import seaborn as sn
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# c:\Users\zhixu\AppData\Local\Programs\Python\Python312\Lib\site-packages\anndata\utils.py:434: FutureWarning: Importing read_csv from `anndata` is deprecated. Import anndata.io.read_csv instead.
#   warnings.warn(msg, FutureWarning)
# c:\Users\zhixu\AppData\Local\Programs\Python\Python312\Lib\site-packages\anndata\utils.py:434: FutureWarning: Importing read_excel from `anndata` is deprecated. Import anndata.io.read_excel instead.
#   warnings.warn(msg, FutureWarning)
# c:\Users\zhixu\AppData\Local\Programs\Python\Python312\Lib\site-packages\anndata\utils.py:434: FutureWarning: Importing read_hdf from `anndata` is deprecated. Import anndata.io.read_hdf instead.
#   warnings.warn(msg, FutureWarning)
# c:\Users\zhixu\AppData\Local\Programs\Python\Python312\Lib\site-packages\anndata\utils.py:434: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Know how cfGen works
train = sc.read_h5ad("CFGen-main/datasets/pbmc3k_train.h5ad")
test = sc.read_h5ad("CFGen-main/datasets/pbmc3k_test.h5ad")

# %%
train
# Out:
# AnnData object with n_obs × n_vars = 2110 × 8573
#     obs: 'n_genes', 'percent_mito', 'n_counts', 'cell_type'
#     var: 'gene_ids', 'n_cells', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm'
#     uns: 'cell_type_colors', 'log1p', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     layers: 'X_counts'
#     obsp: 'connectivities', 'distances'

# %%
train.obs
# Out:
#                   n_genes  percent_mito  n_counts        cell_type
# index
# CCAATTTGAACGTC-1      932      0.010483    2671.0  CD14+ Monocytes
# AACAGCACAAGAGT-1      343      0.024709     688.0  CD14+ Monocytes
# AGAGATGACTGAAC-1      678      0.023834    1972.0      CD4 T cells
# AATAGGGAGAATGA-1      756      0.036002    1861.0      CD8 T cells
# GCCTGACTCTCAAG-1      757      0.014493    2001.0  CD14+ Monocytes
# ...                   ...           ...       ...              ...
# ATGAGCACACAGCT-1     1038      0.019214    3383.0      CD4 T cells
# AAACTTGAAAAACG-1     1116      0.026316    3914.0          B cells
# CTAGGATGAGCCTA-1     1749      0.015681    5867.0          B cells
# GAGGTGGAGTACGT-1      594      0.040951    1514.0      CD4 T cells
# TTGGTACTGGATTC-1      721      0.019118    1883.0          B cells
#
# [2110 rows x 4 columns]

# %%
organoid = sc.read("data/GEJ_harmony.h5ad")
# Out:
# c:\Users\zhixu\AppData\Local\Programs\Python\Python312\Lib\site-packages\anndata\compat\__init__.py:371: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(

# %%
organoid
# Out:
# AnnData object with n_obs × n_vars = 6846 × 2000
#     obs: 'seq_folder', 'nUMI', 'nGene', 'percent.mt', 'mitoRatio', 'percent.rb', 'log10GenesPerUMI', 'log10UMIsPerGene', 'cells', 'sample', 'RNA_snn_res.0.8', 'seurat_clusters', 'pANN_0.25_0.08_90', 'DF.classifications_0.25_0.08_90', 'DF.classifications_0.25_0.08_79', 'DF_hi.lo', 'nCount_RNA', 'nFeature_RNA', 'pANN_0.25_0.07_12', 'DF.classifications_0.25_0.07_12', 'DF.classifications_0.25_0.07_10', 'pANN_0.25_0.15_46', 'DF.classifications_0.25_0.15_46', 'DF.classifications_0.25_0.15_42', 'RNA_snn_res.0.5'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     uns: 'neighbors'
#     obsm: 'X_harmony', 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'HARMONY', 'PCs'
#     layers: 'X_counts'
#     obsp: 'distances'

# %%
organoid.layers['X_counts'] = organoid.X

# %%
organoid.obs
# Out:
#                        seq_folder      nUMI  nGene  percent.mt  mitoRatio  \
# G2B_AAACCCAAGGGAGGCA-1        G2B   66735.0   9353   10.636098   0.106361
# G2B_AAACCCAAGGGATCAC-1        G2B   59544.0   8785   10.054749   0.100547
# G2B_AAACCCAAGTGAGTTA-1        G2B   64304.0   9132   10.663411   0.106634
# G2B_AAACCCACAGCACAGA-1        G2B   70217.0   9416   12.122420   0.121224
# G2B_AAACCCACAGTAGAGC-1        G2B   74411.0  10059    9.546976   0.095470
# ...                           ...       ...    ...         ...        ...
# G2G_TTTGGTTGTTCGATTG-1        G2G  102575.0  10367   10.037534   0.100375
# G2G_TTTGGTTTCGGTAACT-1        G2G  129517.0  10964    9.225816   0.092258
# G2G_TTTGTTGGTACGGTTT-1        G2G   63914.0   9008   11.161874   0.111619
# G2G_TTTGTTGGTTGTCCCT-1        G2G  106870.0   9799   18.692804   0.186928
# G2G_TTTGTTGTCGTAGGAG-1        G2G   89325.0   9928   13.628883   0.136289
#
#                         percent.rb  log10GenesPerUMI  log10UMIsPerGene  \
# ...
